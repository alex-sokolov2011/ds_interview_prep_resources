# %% [markdown]
# # Задача1. Соколова Александра
# ---
# ## Из раздела "Я люблю математику"
# ### Теория вероятностей и мат. статистика
#
# **Условие задачи:**
# Вы подбрасываете кубик (6 граней), после чего у вас есть две возможности:
#
# 1. Взять себе сумму \$, равную выпавшему на кубике числу (выпало 3 – получаете 3\$)
# 1. Отклонить результат первого броска и подбросить кубик второй раз. После чего уже взять себе столько \$, сколько выпало во второй раз (второй бросок отклонять уже нельзя)
#
# Вопросы: Какую стратегию нужно выбрать, чтобы максимизировать ожидаемую прибыль (при каких значениях первого броска нужно перебрасывать?) Почему эта стратегия максимизирует прибыль?
#
# Чему равна ожидаемая прибыль при этой стратегии (математическое ожидание)?

# %% [markdown]
# Для начала посмотрим чему равно матожидание выигрыша без второго броска

# %%
Image(filename='./pictures/1.PNG')

# %% [markdown]
# Теперь перейдем к ответу на вопрос - Какую стратегию выбрать?
#
# Представим себе, что вы кинули кубик первый раз и взяли себе соответствующий выигрыш - 1, 2, 3 и т.д.  А дальше? Дальше вам необходимо сыграть в ту же игру, но как будто вы делаете ставку. Вы ставите то, что выиграли при первом броске.
#
# В случае если в первый раз выпал 1, то вы ставите 1\$. В случае если первый раз выпадает 2, то вы ставите 2\$ и так далее.
#
# При какой ставке целесообразно играть в эту игру, если матожидание выигрыша 3.5\$?
#
# Чтобы не проиграть целесообразно делать ставку ниже величины матожидания 3.5\$. Таким образом беcпроигрышная тактика - это делать второй бросок, если выпало меньше 3.5, то есть 1, 2 или 3.
#
# Посмотрим, какое матожидание выигрыша будет при применении этой стратегии.

# %%
Image(filename='./pictures/2.PNG')

# %% [markdown]
# Комментарии к слайду:
# - исход 11 соответствует выпало 1 при первом броске и 1 при втором броске
# - кол-во исходов для стороны кубика 1 при втором броске равно 3 - это означает что, мы получим 1 после второго подбрасывания в следующих исходах {11,21,31} и их кол-во 3
# - вероятность исхода для стороны кубика 1 при втором броске равно 0,14 = 3/21 - это соответствует формуле расчета вероятности события - кол-во исходов для события (3), разделить на кол-во всех исходов (21)

# %% [markdown]
# Выбрав беспроигрышную стратегию, мы уже получили стратегию с максимальной прибылью и теперь давайте убедимся в этом.
# Допустим мы будем перебрасывать (то есть, бросать кубик во второй раз), если в первый раз выпадает 1,2,3 или 4. Какое будет матожидание выигрыша в этом случае?

# %%
Image(filename='./pictures/3.PNG')

# %% [markdown]
# Из полученных вероятностей исхода видно, что добавление 4 в условие переброса смещает вероятности в более низкие выигрыши, проверим что будет если перебрасывать кубик после двух

# %%
Image(filename='4.png')

# %% [markdown]
# Получаем, что если перебрасывать после того как выпадает 2, то матожидание выше чем 3.71 и равно 3.75. Осталось проверить какое матожидание если, перебрасывать после того как выпадает 1.

# %%
Image(filename='5.png')

# %% [markdown]
# Таким образом,  получаем максимальный размер прибыли 3.75 \$
#
# ***Ответ*** 3.75 \$
#
# Спасибо за внимание
